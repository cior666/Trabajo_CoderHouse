# %% [markdown]
# <a href="https://colab.research.google.com/github/cior666/Trabajo_CoderHouse/blob/main/Datasets_Ciorciari_Conrado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DATASET DE SALARIOS TRABAJANDO EN DATASCIENCE
import pandas as pd
url_salarios_data_science='https://raw.githubusercontent.com/cior666/Trabajo_CoderHouse/refs/heads/main/ds_salaries.csv?token=GHSAT0AAAAAADDYMKVI5OY22J6EQXJUIV3Q2BZZEHA'
df=pd.read_csv(url_salarios_data_science)
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
#DATASET SOBRE ATLETAS OLIMPICOS
import pandas as pd
url_atletas='https://raw.githubusercontent.com/cior666/Trabajo_CoderHouse/refs/heads/main/athlete_events_recortado.csv?token=GHSAT0AAAAAADDYMKVJ4QXO5FPJK5K553T42B2EN2A'
df_atletas=pd.read_csv(url_atletas)
df_atletas.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
import pandas as pd
url_stocks='https://raw.githubusercontent.com/cior666/Trabajo_CoderHouse/refs/heads/main/15%20Years%20Stock%20Data%20of%20NVDA%20AAPL%20MSFT%20GOOGL%20and%20AMZN.csv?token=GHSAT0AAAAAADDYMKVJDIXSM2ZIIEIHMWV42B2FECA'
df_stocks=pd.read_csv(url_stocks)
df_stocks.head()
# Out:
#          Date  Close_AAPL  Close_AMZN  Close_GOOGL  Close_MSFT  Close_NVDA  \
# 0  2010-01-04    6.440330      6.6950    15.609805   23.254051    0.423884
# 1  2010-01-05    6.451465      6.7345    15.541064   23.261557    0.430073
# 2  2010-01-06    6.348847      6.6125    15.149294   23.118809    0.432824
# 3  2010-01-07    6.337109      6.5000    14.796624   22.878376    0.424342
# 4  2010-01-08    6.379242      6.6760    14.993881   23.036165    0.425259
#
#    High_AAPL  High_AMZN  High_GOOGL  High_MSFT  ...  Open_AAPL  Open_AMZN  \
# 0   6.455075     6.8305   15.678546  23.366752  ...   6.422875     6.8125
# 1   6.487878     6.7740   15.636953  23.366746  ...   6.458086     6.6715
# 2   6.477046     6.7365   15.587638  23.351725  ...   6.451466     6.7300
# 3   6.379842     6.6160   15.192630  23.066212  ...   6.372319     6.6005
# 4   6.379844     6.6840   15.024515  23.201460  ...   6.328685     6.5280
#
# ...
